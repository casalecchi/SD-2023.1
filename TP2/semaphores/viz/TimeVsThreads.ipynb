# %%
import pandas as pd

# %%
grafico = pd.DataFrame()

# %%
grafico
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
grafico["N"] = [1, 10, 100, 1000]

# %%
grafico = grafico.set_index(["N"])

# %%
grafico["[1, 1]"] = [37.471, 37.442, 37.503, 37.362]

# %%
grafico["[1, 2]"] = [19.350, 19.372, 19.170, 19.201]

# %%
grafico["[1, 4]"] = [10.021, 9.876, 9.987, 9.978]

# %%
grafico["[1, 8]"] = [5.233, 5.064, 5.086, 5.095]

# %%
import matplotlib.pyplot as plt

# %%
grafico["[2, 1]"] = [37.802, 37.283, 37.249, 37.972]

# %%
grafico["[4, 1]"] = [37.226, 36.315, 37.236, 37.127]

# %%
grafico["[8, 1]"] = [37.120, 37.213, 35.799, 34.539]

# %%
plt.figure(figsize=(10, 10))
plt.plot(grafico.T, marker="o", linestyle=":")
plt.yticks([5, 10, 15, 20, 25, 30, 35, 40])
plt.ylabel("Tempo médio (segundos)", fontsize=18)
plt.xlabel("Threads [Produtoras, Consumidoras]", fontsize=18)
plt.legend(["N=1", "N=10", "N=100", "N=1000"], fontsize="15")
plt.show()
